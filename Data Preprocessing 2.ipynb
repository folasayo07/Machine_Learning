# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
automobile = pd.read_csv('dataset/Automobile price data _Raw_.csv')

# %%
automobile.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 200      sedan          rwd           front       109.1  ...            141
# 201      sedan          rwd           front       109.1  ...            141
# 202      sedan          rwd           front       109.1  ...            173
# 203      sedan          rwd           front       109.1  ...            145
# 204      sedan          rwd           front       109.1  ...            141
#
# ...

# %%
automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %%
automobile.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
automobile.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
automobile['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
automobile['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
automobile['make'] = encoder.fit_transform(automobile['make'])
automobile['make'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: make, dtype: int64

# %%
automobile.head()
# Out:
#    symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 0          3                 ?     0       gas        std          two
# 1          3                 ?     0       gas        std          two
# 2          1                 ?     0       gas        std          two
# 3          2               164     1       gas        std         four
# 4          2               164     1       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
automobile['fuel-type'] = encoder.fit_transform(automobile['fuel-type'])
automobile['fuel-type'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: fuel-type, dtype: int64

# %%
automobile['aspiration'] = encoder.fit_transform(automobile['aspiration'])
automobile['aspiration'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: aspiration, dtype: int64

# %%
automobile['num-of-doors'] = encoder.fit_transform(automobile['num-of-doors'])
automobile['num-of-doors'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    1
# 4    1
# Name: num-of-doors, dtype: int64

# %%
automobile['body-style'] = encoder.fit_transform(automobile['body-style'])
automobile['body-style'].head()
# Out:
# 0    0
# 1    0
# 2    2
# 3    3
# 4    3
# Name: body-style, dtype: int64

# %%
automobile['drive-wheels'] = encoder.fit_transform(automobile['drive-wheels'])
automobile['drive-wheels'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    1
# 4    0
# Name: drive-wheels, dtype: int64

# %%
automobile['engine-location'] = encoder.fit_transform(automobile['engine-location'])
automobile['engine-location'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: engine-location, dtype: int64

# %%
automobile['fuel-system'] = encoder.fit_transform(automobile['fuel-system'])
automobile['fuel-system'].head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: fuel-system, dtype: int64

# %%
auto = automobile[['symboling','normalized-losses','make','wheel-base','length','width','height','curb-weight','engine-type',
'num-of-cylinders','engine-size','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg',
'price','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','fuel-system']]
# or u drop the columns not necessary
#df = var_name.drop([],axis=1)

#d = []
#processdata =

# %%
auto.corr()
# Out:
#                    symboling      make  wheel-base    length     width  \
# symboling           1.000000 -0.118794   -0.531954 -0.357612 -0.232919
# make               -0.118794  1.000000    0.078505  0.119584  0.003783
# wheel-base         -0.531954  0.078505    1.000000  0.874587  0.795144
# length             -0.357612  0.119584    0.874587  1.000000  0.841118
# width              -0.232919  0.003783    0.795144  0.841118  1.000000
# height             -0.541038  0.236233    0.589435  0.491029  0.279210
# curb-weight        -0.227691  0.024015    0.776386  0.877728  0.867032
# engine-size        -0.105790 -0.070918    0.569329  0.683360  0.735433
# compression-ratio  -0.178515  0.138828    0.249786  0.158414  0.181129
# city-mpg           -0.035823  0.053642   -0.470414 -0.670909 -0.642704
# highway-mpg         0.034606  0.050022   -0.544082 -0.704662 -0.677218
# fuel-type           0.194311 -0.113191   -0.308346 -0.212679 -0.233880
# ...

# %%
import seaborn as sns
corr_matrix = auto.corr()
f,ax = plt.subplots(figsize = (30,20))
sns.heatmap(corr_matrix, lw = 2.0,annot= True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')
