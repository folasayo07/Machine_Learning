# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset/train.csv')

# %%
data.tail()
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 4985              NCZ54            CHUKWUDI019              NCZ54_CHUKWUDI019
# 4986              NCZ54            CHUKWUDI027              NCZ54_CHUKWUDI027
# 4987              NCZ54            CHUKWUDI045              NCZ54_CHUKWUDI045
# 4988              NCZ54            CHUKWUDI046              NCZ54_CHUKWUDI046
# 4989              NCZ54            CHUKWUDI049              NCZ54_CHUKWUDI049
#
#       Product_Weight Product_Fat_Content  Product_Shelf_Visibility  \
# 4985             NaN             Low Fat                  0.145952
# 4986             NaN             Low Fat                  0.082956
# 4987           14.65             Low Fat                  0.083528
# 4988           14.65             Low Fat                  0.083359
# 4989           14.65             Low Fat                  0.083489
#
#      Product_Type  Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
# Product_Identifier                4990 non-null object
# Supermarket_Identifier            4990 non-null object
# Product_Supermarket_Identifier    4990 non-null object
# Product_Weight                    4188 non-null float64
# Product_Fat_Content               4990 non-null object
# Product_Shelf_Visibility          4990 non-null float64
# Product_Type                      4990 non-null object
# Product_Price                     4990 non-null float64
# Supermarket_Opening_Year          4990 non-null int64
# Supermarket _Size                 3540 non-null object
# Supermarket_Location_Type         4990 non-null object
# Supermarket_Type                  4990 non-null object
# Product_Supermarket_Sales         4990 non-null float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 506.9+ KB

# %%
data.isnull().head()
# Out:
#    Product_Identifier  Supermarket_Identifier  Product_Supermarket_Identifier  \
# 0               False                   False                           False
# 1               False                   False                           False
# 2               False                   False                           False
# 3               False                   False                           False
# 4               False                   False                           False
#
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0           False                False                     False
# 1           False                False                     False
# 2           False                False                     False
# 3           False                False                     False
# 4           False                False                     False
#
#    Product_Type  Product_Price  Supermarket_Opening_Year  Supermarket _Size  \
# ...

# %%
data.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                     802
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1450
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
data.describe()
# Out:
#        Product_Weight  Product_Shelf_Visibility  Product_Price  \
# count     4188.000000               4990.000000    4990.000000
# mean        12.908838                  0.066916     391.803796
# std          4.703256                  0.053058     119.378259
# min          4.555000                  0.000000      78.730000
# 25%          8.767500                  0.027273     307.890000
# 50%         12.600000                  0.053564     393.860000
# 75%         17.100000                  0.095358     465.067500
# max         21.350000                  0.328391     667.220000
#
#        Supermarket_Opening_Year  Product_Supermarket_Sales
# count               4990.000000                4990.000000
# mean                2004.783567                6103.520164
# std                    8.283151                4447.333835
# min                 1992.000000                  83.230000
# 25%                 1994.000000                2757.660000
# ...

# %%
data['Product_Fat_Content'].value_counts()
# Out:
# Low Fat          3039
# Normal Fat       1773
# Ultra Low fat     178
# Name: Product_Fat_Content, dtype: int64

# %%
data['Product_Type'].value_counts()
# Out:
# Snack Foods              758
# Fruits and Vegetables    747
# Household                567
# Frozen Foods             457
# Canned                   376
# Dairy                    350
# Baking Goods             344
# Health and Hygiene       307
# Meat                     264
# Soft Drinks              261
# Breads                   137
# Hard Drinks              134
# Others                   100
# Starchy Foods             81
# Breakfast                 66
# Seafood                   41
# Name: Product_Type, dtype: int64

# %%
data['Supermarket _Size'].value_counts()
# Out:
# Medium    1582
# Small     1364
# High       594
# Name: Supermarket _Size, dtype: int64

# %%
data['Supermarket_Location_Type'].value_counts()
# Out:
# Cluster 3    1940
# Cluster 2    1581
# Cluster 1    1469
# Name: Supermarket_Location_Type, dtype: int64

# %%
data['Supermarket_Type'].value_counts()
# Out:
# Supermarket Type1    3304
# Grocery Store         724
# Supermarket Type2     500
# Supermarket Type3     462
# Name: Supermarket_Type, dtype: int64

# %%
data['Product_Supermarket_Identifier'].value_counts()
data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
# ...

# %%
#for missing values using the mean values to fill in
#mean = data['Product_Weight'].mean()
#data['Product_Weight'] = data['Product_Weight'].fillna(mean)

data['Product_Weight'] = data['Product_Weight'].fillna(data['Product_Weight'].mean())

# %%
data.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                       0
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1450
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
#The supermarket size is a string nd cnt get the mean of a string value.
#data['Supermarket _Size'] = data['Supermarket _Size'].fillna(data['Supermarket _Size'].mean())

# %%
#sklearn library for converting strings/obj to ints
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['Product_Type'] = encoder.fit_transform(data['Product_Type'])
data['Product_Type'].head()
# Out:
# 0    14
# 1    14
# 2    14
# 3    14
# 4    14
# Name: Product_Type, dtype: int64

# %%
data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility  Product_Type  \
# 0            11.6             Low Fat                  0.068535            14
# 1            11.6             Low Fat                  0.040912            14
# 2            11.6             Low Fat                  0.041178            14
# 3            11.6             Low Fat                  0.041113            14
# 4            11.6       Ultra Low fat                  0.000000            14
#
# ...

# %%
data['Product_Fat_Content'] = encoder.fit_transform(data['Product_Fat_Content'])
data['Product_Fat_Content'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    2
# Name: Product_Fat_Content, dtype: int64

# %%
data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    2                  0.000000
#
#    Product_Type  Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# ...

# %%
data['Supermarket_Location_Type'] = encoder.fit_transform(data['Supermarket_Location_Type'])
data['Supermarket_Location_Type'].head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    2
# 4    1
# Name: Supermarket_Location_Type, dtype: int64

# %%
data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    2                  0.000000
#
#    Product_Type  Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# ...

# %%
data['Supermarket_Type'] = encoder.fit_transform(data['Supermarket_Type'])
data['Supermarket_Type'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    2
# 4    1
# Name: Supermarket_Type, dtype: int64

# %%
data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight  Product_Fat_Content  Product_Shelf_Visibility  \
# 0            11.6                    0                  0.068535
# 1            11.6                    0                  0.040912
# 2            11.6                    0                  0.041178
# 3            11.6                    0                  0.041113
# 4            11.6                    2                  0.000000
#
#    Product_Type  Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# ...

# %%
#data['Supermarket _Size'] = data['Supermarket _Size'].fillna('Large')
#data.head()
#data['Supermarket _Size'] = encoder.fit_transform(data['Supermarket _Size'])
#data['Supermarket _Size'].head()
#data.head()

# %%
dataNew = data[['Supermarket_Type','Product_Weight','Product_Fat_Content','Product_Shelf_Visibility','Product_Type',
                'Supermarket_Opening_Year','Supermarket_Location_Type']]

# %%
dataNew.corr()
# Out:
#                            Supermarket_Type  Product_Weight  \
# Supermarket_Type                   1.000000        0.003061
# Product_Weight                     0.003061        1.000000
# Product_Fat_Content                0.002929       -0.020393
# Product_Shelf_Visibility          -0.190419       -0.022309
# Product_Type                       0.006297        0.030124
# Supermarket_Opening_Year          -0.060821        0.006867
# Supermarket_Location_Type          0.415386       -0.004236
#
#                            Product_Fat_Content  Product_Shelf_Visibility  \
# Supermarket_Type                      0.002929                 -0.190419
# Product_Weight                       -0.020393                 -0.022309
# Product_Fat_Content                   1.000000                  0.057196
# Product_Shelf_Visibility              0.057196                  1.000000
# Product_Type                         -0.118499                 -0.037179
# ...

# %%
import seaborn as sns
corr_matrix = dataNew.corr()
f,ax = plt.subplots(figsize = (18,10))
sns.heatmap(corr_matrix, lw = 2.0,annot= True)
ax.set_title('Correlation Matrix')
# Out:
# Text(0.5,1,'Correlation Matrix')
